# %% [markdown]
# <a href="https://colab.research.google.com/github/areebafatima1807/Flyrank-ml-internship/blob/main/notebooks/Copy_of_w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/areebafatima1807/Flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# Refresh / Content Opportunity Scoring
# I selected this lane because it helps prioritize content pages that should be reviewed first. Since time and resources are limited, it is not possible to update every page at once. This lane uses data to identify pages with the highest improvement opportunity so the team can focus on the most important pages first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# Decision: Decide which content pages should be reviewed first.
# Action: The team will review and update the selected pages.
# Cost of a wrong call: If the wrong pages are selected, important pages may be missed, and time and resources will be wasted.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The starter dataset contains 3,000 rows and 9 columns. Sample median house values include 344,700, 176,500, and 270,500, showing that house prices vary significantly across different locations. These numbers suggest there is enough variation in the data to build a useful model.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# I can claim that this work helps prioritize content pages for review based on the available data. It supports decision-making by identifying pages that may need attention.
#
# I cannot claim that it proves why a page performs poorly or predict future Google rankings with certainty.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
