# %% [markdown]
# <a href="https://colab.research.google.com/github/areebafatima1807/Flyrank-ml-internship/blob/main/work/notebook/Copy_of_w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/areebafatima1807/Flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# Scoring. My lane is CTR opportunity scoring. I want to give each content item a score that represents how much opportunity there may be to improve its click-through rate (CTR). Scoring fits because I want to prioritize pages from highest to lowest opportunity rather than put them into only one category.
# Why scoring?
# Because your eventual output is basically:
# Page A → opportunity score 0.92
# Page B → opportunity score 0.71
# Page C → opportunity score 0.34
# Then the content team can work from the highest scores first.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Target/proxy: ctr_gap. I would use ctr_gap as a measurable proxy for CTR opportunity. It represents the difference between a page's actual CTR and the average CTR for pages in the same position tier. A more negative ctr_gap suggests that the page is getting fewer clicks than comparable pages. The label comes from an observed outcome (CTR) combined with a defined comparison rule (same-position average), rather than from a subjective judgment.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Precision@20. I will measure how many of the top 20 pages ranked as high-opportunity are actually pages that meet my defined CTR-opportunity criterion. A higher Precision@20 is better because it means the model is putting more useful pages at the top of the review queue. The model should beat a simple baseline or random ranking to be considered useful.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# One row = one pseudonymized content item/page. Each row contains observed performance and content-related attributes for that item, including CTR and other search-performance signals. I will use the relevant CTR columns to create the opportunity-scoring view.
# The starter dataset is specifically described as 30,000 pseudonymized content-performance rows, with one row per content item.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# A fixed rule such as “if CTR is below 2%, review the page” is too simple because CTR depends on more than one factor. Pages can have different search positions, impression levels, engagement patterns, content characteristics, and trends. The same CTR can mean different things for pages in different positions. ML can combine several observed signals to produce a more useful opportunity score and rank pages for review instead of relying on one arbitrary cutoff.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
