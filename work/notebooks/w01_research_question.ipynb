# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/areebafatima1807/Flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# Freestyle – Growth / Recovery / Momentum Prediction
#
# I chose a freestyle project because I want to explore how data can be used to identify pages that are likely to improve or decline over time. Instead of following a predefined lane, I want to investigate future content performance and understand which pages may require attention. This project focuses on supporting better content decisions using historical search and content signals.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Decision:
# Which content pages are most likely to decline or improve in the future?
#
# Action:
# The content team can review high-risk pages earlier and update them before their performance drops further.
#
# Cost of a wrong call:
# If the prediction is wrong, important pages may be ignored while time and effort are spent on pages that do not need immediate attention.
#
# Why ML can help:
# Many factors influence content performance. Machine learning can identify patterns in historical data that are difficult to find using simple rules.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# The starter dataset contains 3,000 rows and 9 columns. The average median income is 3.81. These numbers show that the dataset has enough information to explore patterns and build a model for predicting content growth or decline.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
import glob

# Find CSV files
files = glob.glob("sample_data/*.csv")

if files:
    df = pd.read_csv(files[0])

    print("Rows:", len(df))
    print("Columns:", len(df.columns))
    print("Average median income:", round(df["median_income"].mean(), 2))
else:
    print("No CSV file found.")
# Out:
# Rows: 3000
# Columns: 9
# Average median income: 3.81

# %% [markdown]
# This project is intended to support content review by identifying patterns in historical data. The results provide recommendations, not guarantees. Final decisions should always be reviewed by a human because many factors affecting content performance are not included in the dataset.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
